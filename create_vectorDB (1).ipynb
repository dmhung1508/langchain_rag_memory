# %% [markdown]
# ### Part 1: Creating the Vector Database with ChromaDB and Hugging Face Embeddings
# **Introduction:**
# In this part, we will create a vector database using Chroma DB to store embeddings generated by Hugging Face's embedding models. This vector database will serve as the foundation for the retrieval component of our RAG system.

# %%
# !pip install -r requirements.txt
#Or
# Below are the necessary libraries, uncomment the ones you need:
# !pip install langchain
# !pip install chromadb
# !pip install arxiv
# !pip install PyPDF2
# Out:
# Collecting langchain
#   Downloading langchain-0.1.9-py3-none-any.whl (816 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.0/817.0 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.27)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langchain-community<0.1,>=0.0.21 (from langchain)
#   Downloading langchain_community-0.0.24-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 27.9 MB/s eta 0:00:00
# Collecting langchain-core<0.2,>=0.1.26 (from langchain)
#   Downloading langchain_core-0.1.27-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.8/250.8 kB 31.4 MB/s eta 0:00:00
# Collecting langsmith<0.2.0,>=0.1.0 (from langchain)
#   Downloading langsmith-0.1.9-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.6.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.2.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading marshmallow-3.21.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.3 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: anyio<5,>=3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2,>=0.1.26->langchain) (3.7.1)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2,>=0.1.26->langchain) (23.2)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.0->langchain)
#   Downloading orjson-3.9.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 18.8 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.16.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.26->langchain) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.26->langchain) (1.2.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: orjson, mypy-extensions, marshmallow, jsonpointer, typing-inspect, jsonpatch, langsmith, dataclasses-json, langchain-core, langchain-community, langchain
# Successfully installed dataclasses-json-0.6.4 jsonpatch-1.33 jsonpointer-2.4 langchain-0.1.9 langchain-community-0.0.24 langchain-core-0.1.27 langsmith-0.1.9 marshmallow-3.21.0 mypy-extensions-1.0.0 orjson-3.9.15 typing-inspect-0.9.0
# Collecting chromadb
#   Downloading chromadb-0.4.23-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.7/521.7 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.0.3)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.6.1)
# Collecting chroma-hnswlib==0.7.3 (from chromadb)
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 26.8 MB/s eta 0:00:00
# Collecting fastapi>=0.95.2 (from chromadb)
#   Downloading fastapi-0.110.0-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 12.4 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3 (from chromadb)
#   Downloading uvicorn-0.27.1-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.25.2)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.4.2-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.9.0)
# Collecting pulsar-client>=3.1.0 (from chromadb)
#   Downloading pulsar_client-3.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 54.3 MB/s eta 0:00:00
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.17.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 37.2 MB/s eta 0:00:00
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.23.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 8.1 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.23.0-py3-none-any.whl (18 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.44b0-py3-none-any.whl (11 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.23.0-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.15.2)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 9.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.66.2)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.1.1)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.60.1)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.1.2-cp39-abi3-manylinux_2_28_x86_64.whl (698 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 kB 54.4 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.9.0)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 70.8 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.10/dist-packages (from chromadb) (3.9.15)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (1.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (2.0.1)
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi>=0.95.2->chromadb)
#   Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.7)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting importlib-metadata<7.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.62.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.23.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.23.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-proto==1.23.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.23.0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 6.6 MB/s eta 0:00:00
# Collecting opentelemetry-instrumentation-asgi==0.44b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.44b0-py3-none-any.whl (14 kB)
# Collecting opentelemetry-instrumentation==0.44b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.44b0-py3-none-any.whl (28 kB)
# Collecting opentelemetry-semantic-conventions==0.44b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.44b0-py3-none-any.whl (36 kB)
# Collecting opentelemetry-util-http==0.44b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.44b0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (67.7.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading asgiref-3.7.2-py3-none-any.whl (24 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.6)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.2->chromadb) (0.20.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting h11>=0.8 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.2 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 38.6 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 62.5 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 64.3 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 18.0 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2023.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (3.7.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (1.2.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.5.1)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=be8048c8e7b2e66eb7ffd94a069f3a5eafc46ba96fdd0255e5bd2814224c6e2e
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, monotonic, mmh3, websockets, uvloop, python-dotenv, pulsar-client, overrides, opentelemetry-util-http, opentelemetry-semantic-conventions, opentelemetry-proto, importlib-metadata, humanfriendly, httptools, h11, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, uvicorn, starlette, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, coloredlogs, opentelemetry-sdk, opentelemetry-instrumentation, onnxruntime, kubernetes, fastapi, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.1
#     Uninstalling importlib-metadata-7.0.1:
#       Successfully uninstalled importlib-metadata-7.0.1
# Successfully installed asgiref-3.7.2 backoff-2.2.1 bcrypt-4.1.2 chroma-hnswlib-0.7.3 chromadb-0.4.23 coloredlogs-15.0.1 deprecated-1.2.14 fastapi-0.110.0 h11-0.14.0 httptools-0.6.1 humanfriendly-10.0 importlib-metadata-6.11.0 kubernetes-29.0.0 mmh3-4.1.0 monotonic-1.6 onnxruntime-1.17.1 opentelemetry-api-1.23.0 opentelemetry-exporter-otlp-proto-common-1.23.0 opentelemetry-exporter-otlp-proto-grpc-1.23.0 opentelemetry-instrumentation-0.44b0 opentelemetry-instrumentation-asgi-0.44b0 opentelemetry-instrumentation-fastapi-0.44b0 opentelemetry-proto-1.23.0 opentelemetry-sdk-1.23.0 opentelemetry-semantic-conventions-0.44b0 opentelemetry-util-http-0.44b0 overrides-7.7.0 posthog-3.4.2 pulsar-client-3.4.0 pypika-0.48.9 python-dotenv-1.0.1 starlette-0.36.3 uvicorn-0.27.1 uvloop-0.19.0 watchfiles-0.21.0 websockets-12.0
# Collecting arxiv
#   Downloading arxiv-2.1.0-py3-none-any.whl (11 kB)
# Collecting feedparser==6.0.10 (from arxiv)
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.10/dist-packages (from arxiv) (2.31.0)
# Collecting sgmllib3k (from feedparser==6.0.10->arxiv)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->arxiv) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->arxiv) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->arxiv) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->arxiv) (2024.2.2)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6048 sha256=b9530c3cab2a671dddedde92475a1171d0d960e1bc19b008dae4902c74ccc967
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser, arxiv
# Successfully installed arxiv-2.1.0 feedparser-6.0.10 sgmllib3k-1.0.0
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
from langchain.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter
import arxiv
from PyPDF2 import PdfReader

# %% [markdown]
# ### 1. Download an example PDF from arXiv
# For this RAG example we are using the Language Models are Few-Shot Learners paper

# %%
client = arxiv.Client()
search = arxiv.Search(id_list=['2005.14165'])

paper = next(arxiv.Client().results(search))
print(paper.title)
# Out:
# Language Models are Few-Shot Learners

# %% [markdown]
# ##### Download the PDF locally

# %%
path = paper.download_pdf()

# %%
print(path)
# Out:
# ./2005.14165v4.Language_Models_are_Few_Shot_Learners.pdf

# %% [markdown]
# ### 2. Convert the PDF to LangChain Documents
# For this example we will be using the Document format.
# This allows us to include the page_content and pass our metadata which is uses for citing sources

# %%
from langchain.docstore.document import Document

# %%
reader = PdfReader("/content/BAI GIANG TRIET 2021.pdf")
doc = []
for idx, page in enumerate(reader.pages):
    doc.append(Document(page_content=page.extract_text(),
                        metadata={'source': f'{paper.title}', 'page': f'{idx+1}', 'link':f'{paper.entry_id}'},
                        excluded_llm_metadata_keys=['link'],
                        excluded_embed_metadata_keys=['source', 'page', 'link'])
                         )

print(f'Number of pages {len(doc)}')
# Out:
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x1b1 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x1783d for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x17aae for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x15ca4 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x10e60 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x16657 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x12085 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0xfdce for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x13196 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x131a7 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x173e1 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x14f1a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x14d77 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0xf417 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0xa0cc for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0xc9aa for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x1aaff for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x1c1e3 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x17e99 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x1b303 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x1c422 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x1a479 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0xf83c for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:PyPDF2.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-0aeb8923a3eb> in <cell line: 3>()
#       2 doc = []
#       3 for idx, page in enumerate(reader.pages):
# ----> 4     doc.append(Document(page_content=page.extract_text(),
#       5                         metadata={'source': f'{paper.title}', 'page': f'{idx+1}', 'link':f'{paper.entry_id}'},
#       6                         excluded_llm_metadata_keys=['link'],
#
# /usr/local/lib/python3.10/dist-packages/PyPDF2/_page.py in extract_text(self, Tj_sep, TJ_sep, orientations, space_width, visitor_operand_before, visitor_operand_after, visitor_text, *args)
#    1849             orientations = (orientations,)
#    1850
# -> 1851         return self._extract_text(
#    1852             self,
#    1853             self.pdf,
#
# /usr/local/lib/python3.10/dist-packages/PyPDF2/_page.py in _extract_text(self, obj, pdf, orientations, space_width, content_key, visitor_operand_before, visitor_operand_after, visitor_text)
#    1354             )
#    1355             if not isinstance(content, ContentStream):
# -> 1356                 content = ContentStream(content, pdf, "bytes")
#    1357         except KeyError:  # it means no content can be extracted(certainly empty page)
#    1358             return ""
#
# /usr/local/lib/python3.10/dist-packages/PyPDF2/generic/_data_structures.py in __init__(self, stream, pdf, forced_encoding)
#     875                 stream_bytes = BytesIO(stream_data_bytes)
#     876             self.forced_encoding = forced_encoding
# --> 877             self.__parse_content_stream(stream_bytes)
#     878
#     879     def clone(
#
# /usr/local/lib/python3.10/dist-packages/PyPDF2/generic/_data_structures.py in __parse_content_stream(self, stream)
#     941                     peek = stream.read(1)
#     942             else:
# --> 943                 operands.append(read_object(stream, None, self.forced_encoding))
#     944
#     945     def _read_inline_image(self, stream: StreamType) -> Dict[str, Any]:
#
# /usr/local/lib/python3.10/dist-packages/PyPDF2/generic/_data_structures.py in read_object(stream, pdf, forced_encoding)
#    1047             return read_hex_string_from_stream(stream, forced_encoding)
#    1048     elif tok == b"[":
# -> 1049         return ArrayObject.read_from_stream(stream, pdf, forced_encoding)
#    1050     elif tok == b"t" or tok == b"f":
#    1051         return BooleanObject.read_from_stream(stream)
#
# /usr/local/lib/python3.10/dist-packages/PyPDF2/generic/_data_structures.py in read_from_stream(stream, pdf, forced_encoding)
#     148             stream.seek(-1, 1)
#     149             # read and append obj
# --> 150             arr.append(read_object(stream, pdf, forced_encoding))
#     151         return arr
#     152
#
# /usr/local/lib/python3.10/dist-packages/PyPDF2/generic/_data_structures.py in read_object(stream, pdf, forced_encoding)
#    1045             return DictionaryObject.read_from_stream(stream, pdf, forced_encoding)
#    1046         else:
# -> 1047             return read_hex_string_from_stream(stream, forced_encoding)
#    1048     elif tok == b"[":
#    1049         return ArrayObject.read_from_stream(stream, pdf, forced_encoding)
#
# /usr/local/lib/python3.10/dist-packages/PyPDF2/generic/_utils.py in read_hex_string_from_stream(stream, forced_encoding)
#      27         x += tok
#      28         if len(x) == 2:
# ---> 29             txt += chr(int(x, base=16))
#      30             x = b""
#      31     if len(x) == 1:
#
# KeyboardInterrupt:

# %% [markdown]
# ### 3. Prepare the documents by splitting the data
# Now we will split the 75 pages into chucks to be vectorized

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=350, chunk_overlap=15)
texts = text_splitter.split_documents(doc)

print(f'Split into {len(texts)} chunks')
# Out:
# Split into 809 chunks

# %% [markdown]
# #### Setting Device:
# If you are using a Mac or an Nvidia GPU and installed PyTorch correctly the below will use the correct device
# Otherwise it will default to using the CPU
#
# For details on how to install PyTorch for CUDA see the [Get Started page](https://pytorch.org/get-started/locally/)
# If you are not using CUDA with an Nvidia GPU you can uncomment the line below:

# %%
pip install pypdf
# Out:
# Collecting pypdf
#   Downloading pypdf-4.0.2-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.0/284.0 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: pypdf
# Successfully installed pypdf-4.0.2

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader
loader = DirectoryLoader("/content/helo", glob="*.pdf", loader_cls = PyPDFLoader)
documents = loader.load()
text_splitter = RecursiveCharacterTextSplitter(chunk_size=350, chunk_overlap=15)
chunks = text_splitter.split_documents(documents)
# Out:
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x1b1 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x1783d for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x17aae for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x15ca4 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x10e60 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x16657 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# Exception ignored in: <function _xla_gc_callback at 0x7eff01f391b0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 97, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x12085 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0xfdce for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x13196 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x131a7 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x173e1 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x14f1a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x14d77 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0xf417 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0xa0cc for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0xc9aa for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x1aaff for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x1c1e3 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x17e99 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x1b303 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x1c422 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x1a479 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0xf83c for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x6325 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x8e7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x72cd for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x690d for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x782c for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x6707 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x19099 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x17895 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x15f04 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x145d2 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x1d2b8 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x1528d for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x7a for key /Subtype
# WARNING:pypdf.generic._data_structures:Multiple definitions in dictionary at byte 0x976 for key /Subtype

# %%
chunks
# Out:
# [Document(page_content='HỌC VI ỆN CÔNG NGH Ệ BƯU CHÍNH VI ỄN THÔNG  \nKHOA CƠ B ẢN I \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị \n⎯⎯⎯⎯⎯⎯⎯⎯⎯ \n \n \n \n \nBÀI GI ẢNG \nTRIẾT HỌC MÁC - LÊNIN  \n \n \n                               \nTs. Ph ạm Minh Ái  \nThs. Ph ạm Th ị Khánh  \n(Đồng ch ủ biên)  \n                                                              \n \n \n \n \nHÀ N ỘI - 2021', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 0}),
#  Document(page_content='BỘ TRUY ỀN THÔNG THÔNG TIN  \nHỌC VI ỆN CÔNG NGH Ệ BƯU CHÍNH VI ỄN THÔNG  \nKHOA CƠ B ẢN 1 \n \n \n \nTẬP BÀI GI ẢNG \nTRIẾT HỌC MÁC - LÊNIN  \n \n \n \n \nTrình đ ộ: Đại học \nĐối tượng: Sinh viên và gi ảng viên H ọc viện Công ngh ệ Bưu chính Vi ễn thôn g \n \n \n \n \n \n \n \n \n \n \n \n \nHÀ N ỘI - 2021', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 1}),
#  Document(page_content='BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN   \n \n  \n \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 1 MỤC LỤC  \nMỤC LỤC  ................................ ................................ ................................ ......................  1', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 2}),
#  Document(page_content='LỜI NÓI ĐẦU  ................................ ................................ ................................ ................  2 \nCHƯƠNG 1: KHÁI LUẬN VỀ TRIẾT HỌC VÀ TRIẾT HỌC MÁC - LÊNIN  ... 3 \n1.1. Triết học và vấn đề cơ bản của triết học  ................................ ................................ ... 3', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 2}),
#  Document(page_content='1.2. Triết học mác  - lênin và vai trò c ủa triết học mác - lênin trong đ ời sống xã h ội ... 16 \ncâu hỏi ôn tập  ................................ ................................ ................................ .................  27 \nChương 2: CHỦ NGHĨA DUY VẬT BIỆN CHỨNG  ................................ ..............  28', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 2}),
#  Document(page_content='2.1. Vật chất và ý thức  ................................ ................................ ................................ ... 28 \n2.2. Phép biện chứng duy vật  ................................ ................................ ........................  48', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 2}),
#  Document(page_content='2.3. Lý luận nhận thức  ................................ ................................ ................................ ... 77 \nCâu hỏi ôn tập  ................................ ................................ ................................ ................  86', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 2}),
#  Document(page_content='CHƯƠNG 3: CHỦ NGHĨA DUY VẬT LỊCH SỬ  ................................ ...................  88 \n3.1. Học thuyết hình  thái kinh tế - xã hội  ................................ ................................ ...... 88 \n3.2. Giai cấp và dân tộc  ................................ ................................ ...............................  106', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 2}),
#  Document(page_content='3.3. Nhà nước và cách mạng xã hội  ................................ ................................ ............  124 \n3.4. Tồn tại xã hội và ý thức xã hội  ................................ ................................ .............  135', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 2}),
#  Document(page_content='3.5. Triết học về con người  ................................ ................................ ..........................  146 \nCâu hỏi ôn tập  ................................ ................................ ................................ ..............  162', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 2}),
#  Document(page_content='TÀI LIỆU THAM KHẢO  ................................ ................................ .........................  164', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 2}),
#  Document(page_content='BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN   \n \n  \n \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 2 LỜI NÓI ĐẦU  \nNăm 2019 dưới sự chủ trì của Ban Tuyên giáo Trung ương Đảng, Bộ Giáo dục \nvà Đào tạo đã tiến hành đổi mới nội dung, chương trình giảng dạy các mô n lý luận \nchính trị đối với, trên cơ sở đó đã biên soạn giáo trình mới đối với các môn lý luận', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 3}),
#  Document(page_content='chính trị dành cho bậc đại học hệ không chuyên lý luận chính trị, gồm 5 môn  : Triết \nhọc Mác - Lênin, Kinh tế chính trị Mác - Lênin, Chủ nghĩa xã hội khoa học, Tư  tưởng \nHồ Chí Minh, Lịch sử Đảng cộng sản Việt Nam.  \nĐể kịp thời có tài liệu phục vụ việc giảng dạy và học tập các môn học này, được', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 3}),
#  Document(page_content='sự đồng ý của Ban giám đốc Học viện Công nghệ Bưu chính Viễn thông, Bộ môn Lý \nluận chính trị thuộc khoa Cơ bản 1 đã chủ độn g tổ chức biên soạn năm tập bài giảng ở \nnăm môn học chung của Bộ Giáo dục - Đào tạo.  \nMôn học Triết học Mác - Lênin được biên soạn thành một tập bài giảng, với nội', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 3}),
#  Document(page_content='dung là 3 chương theo đúng khung chương trình và kết cấu giáo trình mà Bộ Giáo dục \nvà Đào tạo  chỉ đạo biên soạn. Tập bài giảng tiếp thu chủ yếu nội dung từ giáo trình \nTriết học Mác – Lênin của Bộ Giáo dục và Đào tạo dành cho bậc đại học hệ không \nchuyên lý luận chính trị xuất bản năm 2021.  Tập bài giảng này sẽ giúp cho người học', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 3}),
#  Document(page_content='hiểu một cách có h ệ thống những nội dung cơ bản của Triết học Mác  - Lênin, như: \nkhái lược chung về triết học, triết học Mác – Lênin, nội dung cơ bản của chủ nghĩa duy \nvật biện chứng và chủ nghĩa duy vật lịch sử ...  \nDo tài liệu được biên soạn cho kịp thời gian triển khai th ực hiện chương trình', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 3}),
#  Document(page_content='mới của Bộ Giáo dục và Đào tạo, tập thể tác giả đã hết sức cố gắng song không tránh \nkhỏi những thiếu sót, hạn chế. Rất mong được các đồng nghiệp và sinh viên đóng góp \ný kiến để những lần tái bản sau được hoàn chỉnh hơn.  \nTập thể tác giả  xin trân trọng cảm  ơn!', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 3}),
#  Document(page_content='BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN   \n \n  \n \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 3 CHƯƠNG 1: KHÁI LUẬN VỀ TRIẾT HỌC VÀ TRIẾT HỌC MÁC - LÊNIN  \n \nChương 1 cung c ấp cho sinh viên nh ững tri th ức cơ b ản về triết học nói chung, \ntriết học Mác – Lênin nói riêng, g iúp sinh viên nh ận thức được thực chất cuộc cách', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 4}),
#  Document(page_content='mạng trong lịch sử triết học do C.Mác và Ph.Ăngghen kh ởi tạo, VI.Lênin phát \ntriển, từ đó th ấy đư ợc vai trò c ủa triết học và tri ết học Mác - Lênin trong đ ời sống \nxã hội. \n1.1. TRIẾT HỌC VÀ VẤN ĐỀ CƠ BẢN CỦA TRIẾT HỌC  \n1.1.1. Khái lư ợc về triết học \na. Ngu ồn gốc của triết học', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 4}),
#  Document(page_content='Triết học, với tư cách là d ạng tri th ức lý lu ận xuất hiện sớm nh ất trong l ịch sử tư \ntưởng nhân lo ại, đã có m ột lịch sử ra đời và phát tri ển trên hai ngàn năm. Triết học ra \nđời ở cả Phương Đông và Phương Tây g ần như cùng m ột thời gian (kho ảng từ thế kỷ', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 4}),
#  Document(page_content='VIII đ ến thế kỷ VI tr.CN) t ại các trung tâm văn minh l ớn của nhân lo ại thời Cổ đại. Ý \nthức triết học xuất hiện không ng ẫu nhiên, mà có ngu ồn gốc thực tế từ tồn tại xã h ội \nvới một trình đ ộ phát tri ển nhất định của văn minh , văn hóa và khoa h ọc. Với tính cách', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 4}),
#  Document(page_content='là một hình thái ý th ức xã h ội, triết học có ngu ồn gốc nhận thức và ngu ồn gốc xã h ội.  \nNguồn gốc nhận thức \nTriết học ra đ ời đáp ứng nhu c ầu, khát v ọng khám phá, nh ận thức bản chất của \nthế giới xung quanh và c ủa chính mình trong tính  chỉnh th ể thống nh ất. Triết học với', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 4}),
#  Document(page_content='tư cách h ệ thống tri th ức chung nh ất của con ngư ời về thế giới chỉ có th ể ra đời khi \nnhận thức của con ngư ời đạt tới trình đ ộ tư duy lý lu ận với sự phát tri ển của khả năng \nkhái quát hóa, tr ừu tượng hóa ở một mức độ nhất định để có th ể rút ra b ản chất và', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 4}),
#  Document(page_content='những nguyên lý chung trong s ự tồn tại và bi ến đổi của thế giới. Đi ều đó cũng có \nnghĩa là khi ngôn ng ữ đã phát tri ển hệ thống tiếng nói và ch ữ viết ở một mức độ nhất \nđịnh. B ởi lẽ ngôn ng ữ là phương ti ện và đ ộng lực quan t rọng trong s ự thể hiện và phát \ntriển của tư duy.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 4}),
#  Document(page_content='Nhận thức thế giới là m ột nhu c ầu tự nhiên, khách quan c ủa con ngư ời. Về mặt \nlịch sử, tư duy huy ền tho ại và tín ngư ỡng nguyên th ủy là cách th ức đầu tiên mà con \nngười dùng đ ể giải thích th ế giới bí ẩn xung quanh. Khi trình đ ộ nhận thức còn ở trình', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 4}),
#  Document(page_content='độ thấp, ngư ời nguyên th ủy kết nối những hi ểu biết rời rạc, mơ h ồ, phi lôgíc… c ủa \nmình trong các quan ni ệm đầy xúc c ảm và hoang tư ởng thành nh ững huy ền tho ại để \ngiải thích m ọi hiện tượng.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 4}),
#  Document(page_content='BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN   \n \n  \n \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 4 Trong quá trình sống, đặc biệt là thông qua các ho ạt động th ực tiễn, từng bư ớc \ncon ngư ời có kinh nghi ệm và có tri th ức về thế giới. Ban đ ầu là nh ững tri th ức cụ thể,', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 5}),
#  Document(page_content='riêng l ẻ, cảm tính. Cùng v ới sự tiến bộ của sản xuất và đ ời sống, nh ận thức của con \nngười dần dần đạt đến trình đ ộ cao hơn trong vi ệc giải thích th ế giới một cách h ệ \nthống, lôgíc và nhân qu ả... M ối quan h ệ giữa cái đã bi ết và cái chưa bi ết là đ ối tượng', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 5}),
#  Document(page_content='đồng th ời là đ ộng lực đòi h ỏi nhận thức ngày càng quan tâm sâu s ắc hơn đ ến cái \nchung, nh ững quy lu ật chung. S ự phát tri ển của tư duy tr ừu tượng và năng l ực khái \nquát trong quá trình nh ận thức sẽ đến lúc làm cho các quan đi ểm, quan ni ệm chung \nnhất về thế giới và v ề vai trò c ủa con ngư ời trong th ế giới đó hình thành.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 5}),
#  Document(page_content='Như v ậy, nói đ ến ngu ồn gốc nhận thức của triết học là nói đ ến sự hình thành, \nphát tri ển của tư duy tr ừu tượng, c ủa năng l ực khái quát trong nh ận thức của con \nngười. Tri th ức cụ thể, riêng l ẻ về thế giới đến một giai đo ạn nh ất định ph ải được \ntổng h ợp, trừu tượng hóa, khái quát hóa thành nh ững khái ni ệm, phạm trù, quan', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 5}),
#  Document(page_content='điểm, quy lu ật, luận thuy ết… đ ủ sức phổ quát đ ể giải thích th ế giới. Tri ết học ra đ ời \nđáp ứng nhu c ầu đó c ủa nhận thức. Do nhu c ầu của sự tồn tại, con ngư ời không th ỏa \nmãn v ới các tri th ức riêng l ẻ, cục bộ về thế giới, càng không th ỏa mãn v ới cách gi ải', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 5}),
#  Document(page_content='thích c ủa các tín đi ều và giáo lý tôn giáo. Tư duy tri ết học bắt đầu từ các tri ết lý, t ừ \nsự khôn ngoan, t ừ tình yêu s ự thông thái, d ần hình thành các h ệ thống nh ững tri th ức \nchung nh ất về thế giới.  \nSự phát tri ển của hệ thống ti ếng nói và ch ữ viết đã có vai trò thúc đ ẩy sự phát', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 5}),
#  Document(page_content='triển tư duy khái ni ệm, kh ả năng khái quát hóa, tr ừu tượng hóa c ủa quá trình nh ận thức \ncủa con ngư ời lên m ột trình đ ộ cao hơn. Đây cũng là ti ền đề thúc đ ẩy sự ra đời của các \nhọc thuy ết triết học. \nTriết học chỉ xuất hiện khi kho tàng tri th ức của loài ngư ời đã hình thành đư ợc', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 5}),
#  Document(page_content='một vốn hiểu biết nhất định và trên cơ s ở đó, tư duy con ngư ời cũng đã đ ạt đến trình \nđộ có kh ả năng rút ra đư ợc cái chung trong muôn vàn nh ững sự kiện, hi ện tượng \nriêng l ẻ.  \n Nguồn gốc xã hội  \nGắn liền với ngu ồn gốc nhận thức là ngu ồn gốc xã h ội. Như C.Mác nói: “Tri ết', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 5}),
#  Document(page_content='học không treo lơ l ửng bên ngoài th ế giới, cũng như b ộ óc không t ồn tại bên ngoài con \nngười”1. Triết học ra đ ời khi n ền sản xuất xã h ội đã có s ự phân công lao đ ộng và loài \nngười đã xu ất hiện giai c ấp. Tức là khi ch ế độ cộng sản nguyên th ủy tan rã, ch ế độ', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 5}),
#  Document(page_content='chiếm hữu nô l ệ đã hình thành, phương th ức sản xuất dựa trên s ở hữu tư nhân v ề tư \nliệu sản xuất đã đư ợc xác l ập và ở trình đ ộ khá phát tri ển. Xã h ội có giai c ấp và n ạn áp \n \n1 C.Mác và Ph.Ăngghen (2005), Toàn t ập, t. 1, Nxb Chính tr ị quốc gia, Hà N ội, tr. 156.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 5}),
#  Document(page_content='BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN   \n \n  \n \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 5 bức giai cấp hà kh ắc đã đư ợc luật hóa. Nhà nư ớc, công c ụ trấn áp và đi ều hòa l ợi ích \ngiai c ấp đủ trưởng thành. Lúc này, nhu c ầu ra đ ời các h ọc thuy ết luận giải và b ảo vệ \nquyền lợi của các giai c ấp cũng xu ất hiện.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 6}),
#  Document(page_content='Như v ậy, tri ết học chỉ ra đời khi xã h ội loài n gười đã đ ạt đến một trình đ ộ sản \nxuất xã h ội tương đ ối cao, phân công lao đ ộng xã h ội hình thành, c ủa cải tương đ ối \nthừa dư, tư h ữu hóa tư li ệu sản xuất được luật định, giai c ấp phân hóa rõ và m ạnh, nhà', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 6}),
#  Document(page_content='nước ra đ ời. Trong m ột xã h ội như v ậy, tầng lớp trí t hức xuất hiện, giáo d ục và nhà \ntrường hình thành và phát tri ển, các nhà thông thái đã đ ủ năng l ực tư duy đ ể trừu \ntượng hóa, khái quát hóa, h ệ thống hóa toàn b ộ tri th ức thời đại và các hi ện tượng', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 6}),
#  Document(page_content='của tồn tại xã h ội để xây d ựng nên các h ọc thuy ết, các lý lu ận, các tri ết thuy ết. Với \nsự tồn tại mang tính pháp lý c ủa chế độ sở hữu tư nhân v ề tư liệu sản xuất, của trật tự \ngiai c ấp và c ủa bộ máy nhà nư ớc, tri ết học, tự nó đã mang trong mình tính giai c ấp', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 6}),
#  Document(page_content='sâu s ắc, nó công khai tính  đảng là ph ục vụ cho l ợi ích c ủa những giai c ấp, nh ững lực \nlượng xã h ội nhất định. \nb. Khái ni ệm Tri ết học \nỞ Trung Qu ốc, ch ữ triết (哲) đã có t ừ rất sớm có ý nghĩa là s ự truy tìm b ản chất \ncủa đối tượng, là biểu hiện cao c ủa trí tu ệ, là s ự hiểu biết sâu s ắc của con ngư ời về', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 6}),
#  Document(page_content="toàn bộ thế giới thiên - địa - nhân và đ ịnh hư ớng nhân sinh quan cho con ngư ời. \nỞ Ấn Độ, thu ật ngữ Dar'sana (triết học) ngh ĩa gốc là chiêm ngư ỡng, hàm ý là \ncon đư ờng suy ng ẫm để dẫn dắt con ngư ời đến với lẽ phải, chân lý . \nTheo ti ếng Hy L ạp, triết học là philosophia,  với ngh ĩa là yêu m ến sự thông thái ,", metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 6}),
#  Document(page_content='thể hiện khát v ọng tìm ki ếm chân lý c ủa con ngư ời. Nhà tri ết học đư ợc coi là nhà \nthông thái, có kh ả năng nh ận thức được chân lý, làm sáng t ỏ bản chất của sự vật. \nNhư v ậy, cả ở phương Đông và p hương Tây, ngay t ừ đầu, tri ết học đều được coi \nlà đỉnh cao c ủa trí tu ệ, là s ự nhận thức sâu s ắc về thế giới, đi sâu n ắm bắt bản chất,', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 6}),
#  Document(page_content='chân lý và quy lu ật của thế giới. \nTrải qua quá trình phát tri ển, xu ất hiện nhi ều quan ni ệm khác nhau v ề triết học. \nNhững quan ni ệm đó đ ều có đi ểm giống nhau khi coi tri ết học là h ệ thống tri th ức có \ntính khái quát, xem xét th ế giới trong tính ch ỉnh th ể của nó, tìm ra nh ững nguyên lý, \nquy lu ật chung chi ph ối chỉnh th ể đó.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 6}),
#  Document(page_content='Khái quát l ại, có th ể cho r ằng, triết học là h ệ thống quan đi ểm lí lu ận chung nh ất \nvề thế giới và v ị trí, khả năng c ủa con ngư ời trong th ế giới đó.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 6}),
#  Document(page_content='BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN   \n \n  \n \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 6 c. Vấn đề đối tượng của triết học trong l ịch sử  \nCùng v ới quá trình phát tri ển của xã h ội, của nhận thức và c ủa bản thân tri ết học, \ntrên th ực tế, nội dung c ủa đối tượng của triết học cũng thay đ ổi trong các trư ờng phái', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 7}),
#  Document(page_content='triết học trong nh ững giai đo ạn lịch sử khác nhau.  \nĐối tượng của triết học là các quan h ệ phổ biến và các quy lu ật chung nh ất của \ntoàn b ộ tự nhiên, xã h ội và tư duy.  \nNgay t ừ khi ra đ ời, Ở thời kỳ Cổ đại, nền triết học tự nhiên  của Hy L ạp đã đạt', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 7}),
#  Document(page_content='được những thành t ựu vô cùng r ực rỡ, triết học đã đư ợc xem là hình thái cao nh ất của \ntri th ức, bao hàm trong nó tri th ức của tất cả các lĩnh vực mà không có đ ối tượng riêng.  \nThời kỳ này cũng b ắt đầu xuất hiện quan ni ệm tri ết học là “khoa h ọc của các khoa \nhọc”.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 7}),
#  Document(page_content='học”. \nỞ Tây Âu th ời Trung c ổ, khi quy ền lực của Giáo h ội bao trùm m ọi lĩnh vực đời \nsống xã h ội thì tri ết học trở thành nô lệ của thần học. Nền triết học tự nhiên bị thay \nbằng n ền triết học kinh vi ện. Triết học. Đối tượng của triết học kinh vi ện hầu như', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 7}),
#  Document(page_content='không có thành t ựu gì đáng k ể, chỉ tập trung vào các ch ủ đề như giáo lý  tôn giáo, thiên \nđường, đ ịa ngục, … - những nội dung n ặng về tư biện. \nSự phát tri ển của thời kỳ Phục hưng  và C ận đại đã tạo cơ s ở tri th ức cho s ự \nphát tri ển mới của triết học và các ngành khoa h ọc. Sự phát tri ển của các ngành khoa', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 7}),
#  Document(page_content='học độc lập chuyên ngành trong th ế kỷ XVII, XVIII  cũng từng bư ớc xóa b ỏ vai trò c ủa \ntriết học tự nhiên cũ, làm phá s ản tham v ọng của triết học mu ốn đóng vai trò “khoa \nhọc của các khoa h ọc”. Tri ết học Hêghen  là học thuy ết triết học cuối cùng th ể hiện', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 7}),
#  Document(page_content='tham v ọng đó. Hêghen  tự coi tri ết học của mình là m ột hệ thống tri th ức phổ biến, \ntrong đó nh ững ngành khoa h ọc riêng bi ệt chỉ là nh ững m ắt khâu ph ụ thuộc vào tri ết \nhọc, là lôgíc h ọc ứng dụng. \nHoàn c ảnh kinh t ế - xã hội và s ự phát tri ển mạnh m ẽ của khoa h ọc vào đ ầu thế kỷ', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 7}),
#  Document(page_content='XIX đã d ẫn đến sự ra đời của triết học Mác. Đo ạn tuy ệt triệt để với quan ni ệm tri ết học \nlà “khoa h ọc của các khoa h ọc”, tri ết học Mác xác đ ịnh đối tượng nghiên c ứu của mình \nlà tiếp tục giải quy ết mối quan h ệ giữa tồn tại và tư duy, gi ữa vật chất và ý th ức trên', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 7}),
#  Document(page_content='lập trư ờng duy v ật triệt để và nghiên c ứu những quy lu ật chung nh ất của tự nhiên, xã \nhội và tư duy . Các nhà tri ết học mác xít về sau đã đánh giá, v ới Mác, l ần đầu tiên trong \nlịch sử, đối tượng của triết học được xác l ập một cách h ợp lý. \nVấn đề tư cách khoa h ọc của triết học và đ ối tượng của nó đã gây ra nh ững cu ộc', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 7}),
#  Document(page_content='tranh lu ận kéo dài cho đ ến hiện nay. Nhi ều học thuy ết triết học hiện đại ở phương \nTây mu ốn từ bỏ quan ni ệm truy ền thống v ề triết học, xác đ ịnh đ ối tượng nghiên', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 7}),
#  Document(page_content='BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN   \n \n  \n \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 7 cứu riêng c ho mình như mô t ả những hi ện tượng tinh th ần, phân tích ng ữ nghĩa, chú \ngiải văn b ản... \nMặc dù v ậy, cái chung trong các h ọc thuy ết triết học là nghiên c ứu những vấn đề', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 8}),
#  Document(page_content='chung nh ất của giới tự nhiên, c ủa xã h ội và con ngư ời, mối quan h ệ của con ngư ời, của \ntư duy con ngư ời nói riêng v ới thế giới. \nd. Ch ức năng cơ b ản của triết học \n* Tri ết học - hạt nhân lý lu ận của thế giới quan  \n Thế giới quan  \nNhu c ầu tự nhiên c ủa con ngư ời về mặt nhận thức là mu ốn hiểu biết đến tận', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 8}),
#  Document(page_content='cùng, sâu s ắc và toàn di ện mọi hiện tượng, s ự vật, quá trình. Nhưng tri th ức mà con \nngười và c ả loài ngư ời ở thời nào cũng l ại có h ạn, là ph ần quá nh ỏ bé so v ới thế giới \ncần nhận thức vô t ận bên trong và bên ngoài con ngư ời. Đó là tình hu ống có v ấn đề', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 8}),
#  Document(page_content='(Problematic Situat ion) c ủa mọi tranh lu ận triết học và tôn giáo. B ằng trí tu ệ duy lý, \nkinh nghi ệm và s ự mẫn cảm của mình, con ngư ời buộc phải xác đ ịnh nh ững quan đi ểm \nvề toàn b ộ thế giới làm cơ s ở để định hư ớng cho nh ận thức và hành đ ộng của mình. Đó', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 8}),
#  Document(page_content='chính là th ế giới quan.  Tương t ự như các tiên đ ề, với thế giới quan, s ự chứng minh nào \ncũng không đ ủ căn c ứ, trong khi ni ềm tin l ại mách b ảo độ tin cậy.  \nKhái ni ệm thế giới quan  hiểu một cách ng ắn gọn là h ệ thống quan đi ểm của con \nngười về thế giới. Có th ể định nghĩa: Thế giới quan là khái ni ệm tri ết học chỉ hệ thống', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 8}),
#  Document(page_content='các tri th ức, quan đi ểm, tình c ảm, ni ềm tin, lý tư ởng xác đ ịnh về thế giới và v ề vị trí \ncủa con ngư ời (bao hàm c ả cá nhân, xã h ội và nhân lo ại) trong th ế giới đó. Thế giới \nquan quy đ ịnh các nguyên t ắc, thái đ ộ, giá t rị trong đ ịnh hư ớng nh ận thức và ho ạt \nđộng th ực tiễn của con ngư ời.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 8}),
#  Document(page_content='Thế giới quan thường đư ợc coi là bao hàm trong nó nhân sinh quan - vì nhân \nsinh quan là quan ni ệm của con ngư ời về đời sống v ới các nguyên t ắc, thái đ ộ và \nđịnh hư ớng giá tr ị của hoạt động người. \nNhững thành ph ần chủ yếu của thế giới quan là tri th ức, niềm tin và lý tư ởng.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 8}),
#  Document(page_content='Trong đó tri th ức là cơ s ở trực tiếp hình thành th ế giới quan, nhưng tri th ức chỉ gia \nnhập thế giới quan khi đã đư ợc kiểm nghi ệm ít nhi ều trong th ực tiễn và tr ở thành ni ềm \ntin. Lý tư ởng là trình đ ộ phát tri ển cao nh ất của thế giới quan. V ới tính cách là h ệ quan', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 8}),
#  Document(page_content='điểm ch ỉ dẫn tư duy và hành đ ộng, th ế giới quan là phương th ức để con ngư ời chiếm \nlĩnh hi ện thực, thi ếu thế giới quan, con ngư ời không có phương hư ớng hành đ ộng.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 8}),
#  Document(page_content='BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN   \n \n  \n \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 8 Thế giới quan chung nh ất, ph ổ biến nhất, đư ợc sử dụng (m ột cách ý th ức hoặc \nkhông ý th ức) trong m ọi ngành khoa h ọc và trong toàn b ộ đời sống xã h ội là th ế giới \nquan tri ết học.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 9}),
#  Document(page_content='Nếu xét theo quá trình phát tri ển, có th ể chia th ế giới quan thành 3 lo ại hình cơ \nbản:  \n- Thế giới quan huy ền tho ại là phương th ức cảm nh ận thế giới của ngư ời nguyên \nthủy. Trong th ế giới quan huy ền tho ại, các y ếu tố tri th ức và c ảm xúc, lý trí và tín', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 9}),
#  Document(page_content='ngưỡng, hi ện thực và tư ởng tư ợng, cái th ật và cái ảo,... hòa quy ện vào nhau đ ể thể hiện \nquan ni ệm về thế giới. \n- Thế giới quan tôn giáo  là th ế giới quan d ựa trên ni ềm tin mãnh li ệt vào s ức \nmạnh của lực lượng siêu nhiên, có ý nghĩa ph ổ biến đối với nhận thức và ho ạt động', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 9}),
#  Document(page_content='thực tiễn của con ngư ời. Nhưng do b ản chất là đ ặt niềm tin vào các tín đ iều, coi tín \nngưỡng cao hơn lý trí, cái ảo lấn át cái th ực nên thư ờng dẫn đến sai l ầm, tiêu c ực trong \nhoạt động th ực tiễn.  \n- Thế giới quan tri ết học diễn tả quan ni ệm của con ngư ời dưới dạng hệ thống các', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 9}),
#  Document(page_content='phạm trù, quy lu ật, được coi là trình đ ộ tự giác tr ong quá trình hình thành và phát tri ển \ncủa thế giới quan.  \nTriết học - hạt nhân lý lu ận của thế giới quan  \nVới tư cách là h ệ thống tri th ức lý lu ận chung nh ất của con ngư ời về thế giới, về', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 9}),
#  Document(page_content='vị trí, vai trò c ủa con ngư ời trong th ế giới đó, tri ết học đóng vai trò là h ạt nhân lý lu ận \ncủa thế giới quan. Bởi lẽ: \n+ Th ứ nhất, những vấn đề được triết học đặt ra và tìm l ời giải đáp trư ớc hết là \nnhững vấn đề thuộc thế giới quan. Trong các th ế giới quan khác như th ế giới quan c ủa', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 9}),
#  Document(page_content='các khoa h ọc cụ thể, thế giới quan c ủa các dân t ộc, hay các th ời đại… tri ết học bao gi ờ \ncũng là thành ph ần quan tr ọng, đóng vai trò là nhân t ố cốt lõi. \n+ Thứ hai, thế giới quan triết học đúng đ ắn là ti ền đề quan tr ọng đ ể xác l ập \nphương th ức tư duy h ợp lý và nhân sinh quan tích c ực trong khám phá  và chinh ph ục', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 9}),
#  Document(page_content='thế giới. Triết học giữ vai trò đ ịnh hư ớng cho quá trình c ủng cố và phát tri ển thế giới \nquan c ủa mỗi cá nhân, m ỗi cộng đồng trong l ịch sử. Trình đ ộ phát tri ển của thế giới \nquan là tiêu chí quan tr ọng đánh giá s ự trưởng thành c ủa mỗi cá nhân cũng như c ủa \nmỗi cộng đồng xã h ội nhất định.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 9}),
#  Document(page_content='+ Thứ ba, với các lo ại thế giới quan tôn giáo, th ế giới quan kinh nghi ệm hay th ế \ngiới quan thông thư ờng…, tri ết học bao gi ờ cũng có ảnh hư ởng và chi ph ối, dù có th ể \nkhông t ự giác.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 9}),
#  Document(page_content='BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN   \n \n  \n \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 9 + Thứ tư, thế giới quan tri ết học như th ế nào s ẽ quy đ ịnh các th ế giới quan và các \nquan ni ệm khác như th ế. \nNhư v ậy, tri ết học với tính cách là h ạt nhân lý lu ận, trên th ực tế, chi ph ối mọi thế', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 10}),
#  Document(page_content='giới quan, dù ngư ời ta có chú ý và th ừa nhận điều đó hay không.  \n*Triết học cung c ấp phương ph áp lu ận chung nh ất \nCùng v ới chức năng cung c ấp thế giới quan, ch ức năng cung c ấp phương pháp \nluận là m ột trong hai ch ức năng cơ b ản nh ất của triết học, nó đ ịnh hư ớng cho con', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 10}),
#  Document(page_content='người xác đ ịnh, lựa chọn, sử dụng phương pháp trong nh ận thức và th ực tiễn một các h \nhiệu quả. \nPhương pháp lu ận được hiểu là h ệ thống các nguyên lý, quan đi ểm (trư ớc hết là \nnhững nguyên lý, quan đi ểm liên quan đ ến thế giới quan) làm cơ s ở, có tác d ụng ch ỉ', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 10}),
#  Document(page_content='đạo, xây d ựng các phương pháp, xác đ ịnh ph ạm vi, kh ả năng áp d ụng các phương pháp \nvà định hư ớng cho vi ệc nghiên c ứu tìm tòi cũng như vi ệc lựa chọn, vận dụng phương \npháp. Nói cách khác thì phương pháp lu ận chính là lý lu ận về phương pháp, bao hàm \nhệ thống các phương pháp, th ế giới quan và nhân sinh quan c ủa ngư ời sử dụng phương', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 10}),
#  Document(page_content='pháp và cá c nguyên t ắc để giải quy ết các v ấn đề đã đặt ra có hi ệu quả cao nh ất. \nCũng như phương pháp, có th ể phân ra các c ấp độ phương pháp lu ận. Phương \npháp lu ận có nhi ều cấp độ khác nhau: phương pháp lu ận ngành là phương pháp lu ận \ncủa các ngành khoa h ọc cụ thể; phương pháp lu ận chung là các quan đi ểm, nguyên t ắc', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 10}),
#  Document(page_content='chung hơn c ấp độ ngành, dùng đ ể xác đ ịnh phương pháp hay phương pháp lu ận của \nnhóm ngành có đ ối tượng nghiên c ứu chung nào đó; phương pháp lu ận chung nh ất \n(phương pháp lu ận triết học) khái quát các quan đi ểm, nguyên t ắc chung nh ất làm cơ \nsở cho vi ệc xác đ ịnh các phương pháp lu ận ngành, chung và các phương pháp ho ạt', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 10}),
#  Document(page_content='động cụ thể của nhận thức và th ực tiễn.  \nVai trò c ủa phương pháp lu ận triết học đối với nhận thức và th ực tiễn thể hiện ở \nchỗ nó ch ỉ đạo sự tìm k iếm, xây d ựng, lựa chọn và v ận dụng các phương pháp đ ể thực \nhiện hoạt động nh ận thức và th ực tiễn, đóng vai trò đ ịnh hư ớng trong quá trình tìm tòi, \nlựa chọn và v ận dụng phương pháp.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 10}),
#  Document(page_content='1.1.2. Vấn đề cơ bản của triết học  \na. Nội dung v ấn đề cơ bản của triết học  \nTriết học cũng như nh ững ngành khoa h ọc khác ph ải giải quy ết rất nhiều vấn đề \ncó liên quan đ ến nhau, t ạo nên h ệ vấn đề thuộc đối tượng nghiên c ứu của mình. Trong \nđó, v ấn đề có tính ch ất nền tảng và là đi ểm xu ất phát đ ể giải quy ết những vấn đề khác', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 10}),
#  Document(page_content='được gọi là v ấn đề cơ bản của triết học.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 10}),
#  Document(page_content='BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN   \n \n  \n \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 10 Ph.Ăngghen vi ết: “Vấn đề cơ bản lớn của mọi triết học, đặc biệt là c ủa triết học \nhiện đại, là v ấn đề quan h ệ giữa tư duy v ới tồn tại”1. \nGiải quy ết vấn đề cơ bản của triết học không ch ỉ xác đ ịnh đư ợc nền tảng và đi ểm', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 11}),
#  Document(page_content='xuất phát đ ể giải quy ết những vấn đề khác c ủa triết học mà nó còn là tiêu chu ẩn để xác \nđịnh lập trư ờng tri ết học và các trư ờng phái tri ết học đấu tranh v ới nhau t ạo thành \nxung l ực cho s ự phát tri ển của lịch sử triết học. \nVấn đề cơ bản của triết học có hai m ặt, trả lời hai câu h ỏi lớn.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 11}),
#  Document(page_content='Mặt thứ nhất (bản thể luận): Giữa ý th ức và v ật chất thì cái nào có trư ớc, cái nào \ncó sau, cái nào quy ết định cái nào?  \nMặt thứ hai (nhận thức luận): Con ngư ời có kh ả năng nh ận thức được thế giới \nhay không?  \nCách tr ả lời hai câu h ỏi trên quy đ ịnh lập trư ờng của nhà tri ết học và c ủa trư ờng', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 11}),
#  Document(page_content='phái tri ết học, xác đ ịnh vi ệc hình thành các trư ờng phái l ớn của triết học. \nb. Ch ủ nghĩa duy v ật và ch ủ nghĩa duy tâm  \nViệc giải quy ết mặt thứ nhất của vấn đề cơ bản của triết học đã chia các nhà tri ết \nhọc thành hai trư ờng phái l ớn: \n- Chủ nghĩa duy v ật: trư ờng phái tri ết học cho r ằng th ế giới vật chất có trư ớc,', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 11}),
#  Document(page_content='sinh ra và quy ết định ý th ức. \n- Chủ nghĩa duy tâm: trư ờng phái tri ết học cho r ằng ý th ức, tinh th ần có trư ớc, \nsinh ra và quy ết định th ế giới vật chất. \n* Chủ nghĩa duy v ật: Cho đ ến nay, ch ủ nghĩa duy v ật đã đư ợc thể hiện dưới ba \nhình th ức cơ b ản: chủ nghĩa duy v ật chất phác, ch ủ nghĩa duy v ật siêu hình và ch ủ', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 11}),
#  Document(page_content='nghĩa duy v ật biện chứng. \n+ Chủ nghĩa duy v ật chất phác là kết quả nhận thức của các nhà tri ết học duy v ật \nthời Cổ đại. Ch ủ nghĩa duy v ật thời kỳ này th ừa nhận tính th ứ nhất của vật chất nhưng \nđồng nh ất vật chất với một hay m ột số chất cụ thể của vật chất và đưa ra nh ững kết', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 11}),
#  Document(page_content='luận mà v ề sau ngư ời ta th ấy mang n ặng tính tr ực quan, ngây thơ, ch ất phác. Tuy h ạn \nchế do trình đ ộ nhận thức thời đại về vật chất nhưng ch ủ nghĩa duy v ật chất phác th ời \nCổ đại đã xu ất phát t ừ chính th ế giới vật chất để giải thích th ế giới vật chất.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 11}),
#  Document(page_content='+ Chủ nghĩa duy v ật siêu hình là hình th ức cơ b ản thứ hai trong l ịch sử của chủ \nnghĩa duy v ật, thể hiện khá rõ ở các nhà tri ết học thế kỷ XV đ ến thế kỷ XVIII và đi ển \nhình là ở thế kỷ thứ XVII, XVIII. Đây là th ời kỳ mà cơ h ọc cổ điển đạt được những', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 11}),
#  Document(page_content='1 C.Mác và Ph.Ăngghen (1995), Toàn t ập, t. 21, Nxb Chính tr ị quốc gia, Hà N ội, tr. 403.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 11}),
#  Document(page_content='BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN   \n \n  \n \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 11 thành t ựu rực rỡ nên trong khi ti ếp tục phát tri ển quan đi ểm ch ủ nghĩa duy v ật thời Cổ \nđại, chủ nghĩa duy v ật giai đo ạn này ch ịu sự tác đ ộng m ạnh m ẽ của phương pháp tư', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 12}),
#  Document(page_content='duy siêu hình, cơ gi ới - phương pháp nhìn th ế giới như m ột cỗ máy kh ổng lồ mà m ỗi \nbộ phận tạo nên th ế giới đó v ề cơ bản là ở trong tr ạng thái bi ệt lập và t ĩnh tại. Tuy \nkhông ph ản ánh đúng hi ện thực trong toàn c ục nhưng ch ủ nghĩa duy vật siêu hình đã', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 12}),
#  Document(page_content='góp ph ần không nh ỏ vào vi ệc đẩy lùi th ế giới quan duy tâm và tôn giáo, đ ặc biệt là ở \nthời kỳ chuy ển tiếp từ đêm trư ờng Trung c ổ sang th ời Phục hưng.  \n+ Chủ nghĩa duy v ật biện chứng là hình th ức cơ b ản thứ ba của chủ nghĩa duy \nvật, do C.Mác và Ph.Ăngghen xây d ựng vào nh ững năm 40 c ủa thế kỷ XIX, sau đó', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 12}),
#  Document(page_content='được V.I.Lênin phát tri ển. Với sự kế thừa tinh hoa c ủa các h ọc thuy ết triết học trư ớc \nđó và s ử dụng khá tri ệt để thành t ựu của khoa h ọc đương th ời, chủ nghĩa duy v ật biện \nchứng, ngay t ừ khi m ới ra đ ời đã kh ắc phục được hạn chế của chủ nghĩa duy v ật chất', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 12}),
#  Document(page_content='phác th ời Cổ đại, chủ nghĩa duy v ật siêu hình và là đ ỉnh cao trong s ự phát tri ển của \nchủ nghĩa duy v ật. Ch ủ nghĩa duy v ật biện chứng không ch ỉ phản ánh hi ện thực đúng \nnhư chính b ản thân nó t ồn tại mà còn là m ột công c ụ hữu hiệu giúp nh ững lực lượng \ntiến bộ trong xã h ội cải tạo hiện thực ấy.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 12}),
#  Document(page_content='Sơ đồ: Ba hình th ức cơ b ản của chủ nghĩa duy v ật \n* Chủ nghĩa duy tâm : Chủ nghĩa duy tâm g ồm có hai hình th ức: chủ nghĩa duy \ntâm ch ủ quan và ch ủ nghĩa duy tâm khách quan . \n+ Chủ nghĩa duy tâm ch ủ quan thừa nhận tính th ứ nhất của ý thức con ngư ời.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 12}),
#  Document(page_content='Trong khi ph ủ nhận sự tồn tại khách quan c ủa hiện thực, ch ủ nghĩa duy tâm ch ủ quan \nkhẳng định m ọi sự vật, hiện tượng ch ỉ là ph ức hợp của những cảm giác.  \n+ Chủ nghĩa duy tâm khách quan cũng th ừa nhận tính th ứ nhất của ý th ức nhưng \ncoi đó là là thứ tinh th ần khách quan có trư ớc và t ồn tại độc lập với con ngư ời. Th ực', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 12}),
#  Document(page_content='thể tinh th ần khách quan này thư ờng đư ợc gọi bằng nh ững cái tên khác nhau như ý \nniệm, tinh th ần tuy ệt đối, lý tính th ế giới, v.v.. C hủ nghĩa duy tâm  khách quan  đã th ừa \nnhận sự sáng t ạo của một lực lượng siêu nhiên nào đó đ ối với toàn b ộ thế giới. Vì v ậy,', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 12}),
#  Document(page_content='BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN   \n \n  \n \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 12 tôn giáo thư ờng sử dụng các h ọc thuy ết duy tâm  khách quan  làm cơ s ở lý lu ận, luận \nchứng cho các quan đi ểm của mình . \nVề phương di ện nhận thức luận, chủ nghĩa duy tâm b ắt ngu ồn từ cách xem xét', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 13}),
#  Document(page_content='phiến diện, tuy ệt đối hóa, th ần thánh hóa m ột mặt, một đặc tính nào đó c ủa quá trình \nnhận thức mang tính bi ện chứng của con ngư ời. Bên c ạnh ngu ồn gốc nhận thức, ch ủ \nnghĩa duy tâm ra đ ời còn có ngu ồn gốc xã h ội. Sự tách r ời lao đ ộng trí óc v ới lao đ ộng', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 13}),
#  Document(page_content='chân tay và đ ịa vị thống tr ị của lao đ ộng trí óc đ ối với lao đ ộng chân tay trong các xã \nhội trước đây đã t ạo ra quan ni ệm về vai trò quy ết định của nhân t ố tinh th ần. Trong \nlịch sử, giai c ấp thống tr ị và nhi ều lực lượng xã h ội đã t ừng ủng hộ, sử dụng ch ủ nghĩa', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 13}),
#  Document(page_content='duy tâm làm n ền tảng lý lu ận cho nh ững quan đi ểm chính tr ị - xã hội của mình.  \nHọc thuy ết triết học nào th ừa nhận chỉ một trong hai th ực thể (vật chất hoặc tinh \nthần) là b ản nguyên (ngu ồn gốc) của thế giới, quy ết định sự vận động của thế giới \nđược gọi là nhất nguyên lu ận (nhất nguyên lu ận duy v ật hoặc nhất nguyên lu ận duy', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 13}),
#  Document(page_content='tâm). Trong l ịch sử triết học cũng có nh ững nhà tri ết học giải thích th ế giới bằng cả hai \nbản nguyên v ật chất và tinh th ần, xem v ật chất và tinh th ần là hai b ản nguyên có th ể \ncùng quy ết định ngu ồn gốc và s ự vận động của thế giới. Học thuy ết triết học như v ậy', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 13}),
#  Document(page_content='được gọi là nhị nguyên lu ận. Những ngư ời nhị nguyên lu ận thư ờng là nh ững ngư ời, \ntrong trư ờng h ợp giải quy ết một vấn đề nào đó, ở vào m ột thời điểm nh ất định, là \nngười duy v ật, nhưng ở vào m ột thời điểm khác, và khi gi ải quy ết một vấn đề khác, l ại', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 13}),
#  Document(page_content='là ngư ời duy tâm. Song, xét đ ến cùng nh ị nguyên lu ận thu ộc về chủ nghĩa duy tâ m. \nc. Thuy ết Có th ể biết (thuy ết Khả tri) và thuy ết Không th ể biết (thuy ết Bất khả \ntri) \nĐây là k ết quả của cách gi ải quy ết mặt thứ hai v ấn đề cơ bản của triết học.  \n*Thuy ết Có th ể biết', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 13}),
#  Document(page_content='Học thuy ết triết học khẳng định kh ả năng nh ận thức của con ngư ời được gọi là \nthuyết Có th ể biết (thuyết Khả tri). Thuy ết Khả tri kh ẳng định con ngư ời về nguyên \ntắc có th ể hiểu được bản chất của sự vật. Nói cách khác, c ảm giác, bi ểu tượng, quan \nniệm và nói chung ý th ức mà con ngư ời có đư ợc về sự vật về nguyên t ắc, là phù', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 13}),
#  Document(page_content='hợp với bản thân s ự vật. Thuy ết Kh ả tri th ừa nhận kh ả năng nh ận thức vô t ận của \ncon ngư ời, ch ỉ có cái con ngư ời chưa bi ết chứ không có cái con ngư ời không th ể \nbiết. \nNhững ngư ời theo Kh ả tri lu ận tin tư ởng rằng, nh ận thức là m ột quá trình \nkhông ng ừng đi sâu khám phá b ản chất sự vật. Nh ận thức là m ột quá trình vô t ận,', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 13}),
#  Document(page_content='không có gi ới hạn tuy ệt đối cuối cùng c ủa khả năng nh ận thức. \n *Thuy ết Không th ể biết', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 13}),
#  Document(page_content='BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN   \n \n  \n \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 13 Học thuy ết triết học phủ nhận kh ả năng nh ận thức của con ngư ời được gọi là \nthuyết Không th ể biết (thuy ết Bất khả tri). Theo thuy ết này, con ngư ời, về nguyên t ắc, \nkhông th ể hiểu đư ợc bản chất của đối tượng. B ất khả tri không tuy ệt đối phủ nhận', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 14}),
#  Document(page_content='những th ực tại siêu nhiên hay th ực tại được cảm giác c ủa con ngư ời, nhưng v ẫn khẳng \nđịnh con ngư ời không th ể nhận thức được bản chất của thế giới, vì nó  tuyệt đối đều \nnằm ngoài kinh nghi ệm của con ngư ời về thế giới. Thuy ết Bất khả tri phủ nhận khả \nnăng vô h ạn của nhận thức con ngư ời.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 14}),
#  Document(page_content='Ít nhi ều liên quan đ ến thuy ết bất khả tri là s ự ra đời của trào lưu hoài nghi lu ận từ \ntriết học Hy L ạp cổ đại. Nh ững ngư ời theo trào lưu này nâng s ự hoài nghi lên thành \nnguyên t ắc cực đoan trong vi ệc xem xét tri th ức đã đ ạt được và cho r ằng con ngư ời', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 14}),
#  Document(page_content='không th ể đạt đến chân lý khách quan.  Tuy c ực đoan v ề mặt nhận thức, nhưng Hoài \nnghi lu ận thời Phục hưng đã gi ữ vai trò quan tr ọng trong cu ộc đấu tranh ch ống hệ tư \ntưởng và quy ền uy c ủa Giáo h ội Trung c ổ. Hoài nghi lu ận thừa nhận sự hoài nghi đ ối \nvới cả Kinh thánh và các tín đi ều tôn giáo.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 14}),
#  Document(page_content='Sơ đồ: Khái quát v ấn đề cơ bản của triết học \n1.1.3. Bi ện chứng và siêu hình  \na. Khái ni ệm biện chứng và siêu hình trong l ịch sử  \nCác khái ni ệm “bi ện chứng” và “siêu hình” trong l ịch sử triết học được dùng th eo \nmột số nghĩa khác nhau. Nghĩa xu ất phát c ủa từ “biện chứng” là ngh ệ thuật tranh lu ận', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 14}),
#  Document(page_content='để tìm chân lý b ằng cách phát hi ện mâu thu ẫn trong cách l ập luận (do Xôcrát dùng).', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 14}),
#  Document(page_content='BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN   \n \n  \n \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 14 Nghĩa xu ất phát c ủa từ “siêu hình” là dùng đ ể chỉ triết học, với tính cách là khoa học \nsiêu c ảm tính, phi th ực nghi ệm (do Arixt ốt dùng)  \nTrong tri ết học hiện đại, đặc biệt là tri ết học mácxít, chúng đư ợc dùng, trư ớc hết', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 15}),
#  Document(page_content='để chỉ hai phương pháp tư duy chung nh ất đối lập nhau, đó là phương pháp bi ện chứng \nvà phương pháp siêu hình . \nb. Sự đối lập giữa hai phương pháp tư duy  \nPhương pháp siêu hình  là phương pháp:  \n+ Nh ận thức đối tượng ở trạng thái cô l ập, tách r ời đối tượng ra kh ỏi các quan h ệ', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 15}),
#  Document(page_content='được xem xét và coi các m ặt đối lập với nhau có m ột ranh gi ới tuyệt đối, chỉ nhìn nh ận \nsự vật ở một mặt, một thuộc tính nào đó . \n+ Nh ận thức đối tượng ở trạng thái t ĩnh; đ ồng nh ất đối tượng với trạng thái tĩnh \nnhất thời đó. Th ừa nhận sự biến đổi chỉ là sự biến đổi về số lượng, v ề các hi ện tượng', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 15}),
#  Document(page_content='bề ngoài. Nguyên nhân c ủa sự biến đổi coi là n ằm ở bên ngoài đ ối tượng. \nPhương pháp siêu hình có c ội ngu ồn hợp lý c ủa nó t ừ trong khoa h ọc cổ điển. \nMuốn nhận thức bất kỳ một đối tượng nào, trư ớc hết con ngư ời phải tách đ ối tượng ấy \nra kh ỏi những liên h ệ nhất định và nh ận thức nó ở trạng thái không bi ến đổi trong m ột', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 15}),
#  Document(page_content='không gian và th ời gian xác đ ịnh. Đó là phương pháp đư ợc đưa t ừ toán h ọc và v ật lý h ọc \ncổ điển vào các khoa h ọc thực nghi ệm và vào tri ết học. Song phương pháp siêu hình ch ỉ \ncó tác d ụng tr ong m ột phạm vi nh ất định bởi hiện thực khách quan, trong b ản chất của', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 15}),
#  Document(page_content='nó, không r ời rạc và không ngưng đ ọng như phương pháp tư duy này quan ni ệm. \nPh.Ăngghen đã ch ỉ rõ, phương pháp siêu hình “ch ỉ nhìn th ấy những sự vật riêng \nbiệt mà không nhìn thấy mối liên h ệ qua l ại giữa những sự vật ấy, ch ỉ nhìn th ấy sự tồn \ntại của những sự vật ấy mà không nhìn th ấy sự phát sinh và s ự tiêu vong c ủa những sự', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 15}),
#  Document(page_content='vật ấy, ch ỉ nhìn th ấy trạng thái t ĩnh của những sự vật ấy mà quên m ất sự vận động của \nnhững sự vật ấy, ch ỉ nhìn th ấy cây mà không th ấy rừng”1. \n Phương pháp bi ện chứng là phương pháp:  \n+ Nh ận thức đối tượng trong các m ối liên h ệ phổ biến vốn có c ủa nó. Đ ối tượng', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 15}),
# ...
#  Document(page_content='sản xuất thống trị nhất định. Đó là giai cấp chủ nô và nô lệ trong xã hội chiếm hữu nô \nlệ; giai cấp địa chủ và nông dân trong xã hội phong kiến; giai cấp tư sản và vô sản \ntrong xã hội tư bản chủ nghĩa.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 110}),
#  Document(page_content='BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN   \n \n  \n \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 110 Những giai cấp không cơ bản là những giai cấp gắn với phương thức sản xuất tàn \ndư, hoặc mầm mống trong xã hội. Những giai cấp không cơ bản gắn  với phương thức \nsản xuất tàn dư, như nô lệ trong buổi đầu xã hội phong kiến; địa chủ và nông nô trong', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 111}),
#  Document(page_content='buổi đầu xã hội tư bản... Những giai cấp không cơ bản gắn với phương thức sản xuất \nmầm mống, như tiểu chủ, tiểu thương, tư sản, vô sản trong giai đoạn cu ối xã hội phong \nkiến... Trong quá trình phát triển của lịch sử, các giai cấp cơ bản và không cơ bản có \nthể có sự chuyển hoá do sự phát triển và thay thế nhau của các phương thức sản xuất.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 111}),
#  Document(page_content='Trong xã hội có giai cấp, ngoài những giai cấp cơ bản và không cơ bản còn có \ncác tầng lớp và nhóm xã hội nhất định (như tầng lớp trí thức, nhân sĩ, giới tu hành...). \nMặc dù các tầng lớp, nhóm xã hội không có địa vị kinh tế độc lập, song nó có vai trò \nquan trọng trong sự phát triển của xã hội nói chung và tuỳ thuộc vào đi ều kiện lịch sử', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 111}),
#  Document(page_content='cụ thể mà nó có thể phục vụ cho giai cấp này, hoặc giai cấp khác. Các tầng lớp xã hội \nnày luôn bị phân hoá dưới tác động của sự vận động nền sản xuất vật chất xã hội.  \nKết cấu xã hội - giai cấp luôn có sự vận động và biến đổi không ngừng. Sự  vận \nđộng, biến đổi đó diễn ra không chỉ khi xã hội có sự chuyển biến các phương thức sản', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 111}),
#  Document(page_content='xuất, mà cả trong quá trình phát triển của mỗi phương thức sản xuất.  \nPhân tích kết cấu xã hội - giai cấp và khuynh hướng vận động, phát triển của nó \ncó ý nghĩa cực k ỳ quan trọng cả về lý luận và thực tiễn trong điều kiện hiện nay. Phân \ntích khoa học kết cấu xã hội - giai cấp giúp cho chính đảng của giai cấp vô sản xác', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 111}),
#  Document(page_content='định đúng các mâu thuẫn cơ bản, mâu thuẫn chủ yếu của xã hội; nhận thức đúng địa \nvị, vai trò và thái độ chính trị của mỗi giai cấp. Trên cơ sở đó để xác định đối tượng và \nlực lượng cách mạng; nhiệm vụ và giai cấp lãnh đạo cách mạng .v.v..  \nb. Đấu tranh giai cấp  \n* Tính tất yếu và thực chất của đấu tranh giai cấp', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 111}),
#  Document(page_content='Như vậy, các nhà kinh điển đã chỉ ra tính tất  yếu và thực chất của đấu tranh giai \ncấp trong xã hội có đối kháng giai cấp.  \n- Đấu tranh giai cấp là tất yếu do sự đối lập về lợi ích căn bản không thể điều \nhoà được giữa các giai cấp.  Trong xã hội có giai cấp, đấu tranh giai cấp là quy luật tất', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 111}),
#  Document(page_content='yếu của xã  hội. Tính tất yếu của đấu tranh giai cấp xuất phát từ tính tất yếu kinh tế, \nnguyên nhân là do sự đối kháng về lợi ích cơ bản giữa giai cấp bị trị và giai cấp thống \ntrị. Đấu tranh giai cấp là một hiện tượng lịch sử khách quan, không phải do một lý \nthuyết x ã hội nào tạo ra, cũng không phải do ý muốn chủ quan của một lực lượng xã', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 111}),
#  Document(page_content='hội hay một cá nhân nào nghĩ ra. Ở đâu và khi nào còn áp bức, bóc lột, thì ở đó và khi \nđó còn đấu tranh giai cấp chống lại áp bức, bóc lột. Thực tiễn lịch sử của xã hội loài \nngười đã  và đang chứng minh điều đó.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 111}),
#  Document(page_content='BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN   \n \n  \n \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 111 - Đấu tranh giai cấp là cuộc đấu tranh của các tập đoàn người to lớn có lợi ích \ncăn bản đối lập nhau trong một phương thức sản xuất xã hội nhất định .  \nTrong xã hội có giai cấp, đấu tranh giai cấp chủ yếu và trước hết là cuộc đấ u', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 112}),
#  Document(page_content='tranh của hai giai cấp cơ bản đại diện cho phương thức sản xuất thống trị trong xã hội \n(nô lệ và chủ nô; nông dân và địa chủ; vô sản và tư sản). Đó là các giai cấp có lợi ích \ncăn bản đối lập nhau. Cuộc đấu tranh giữa hai giai cấp cơ bản trong một xã hội là \nnhững cuộc đấu tranh giai cấp điển hình, đặc trưng cho chế độ xã hội đó. Về cơ bản', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 112}),
#  Document(page_content='các giai cấp, tầng lớp xã hội còn lại đều có lợi ích ít, nhiều gắn với việc đánh đổ giai \ncấp thống trị bóc lột. Song do lợi ích giữa các tập đoàn là hết sức khác nhau, nê n thái \nđộ của các giai cấp tham gia vào cuộc đấu tranh chung không giống nhau. Chỉ có giai \ncấp đại diện cho phương thức sản xuất mới và quần chúng cùng khổ là lực lượng tham', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 112}),
#  Document(page_content='gia đông đảo, tích cực nhất. Cuộc đấu tranh của các giai cấp cơ bản là trục chính thu \nhút các giai cấp không cơ bản và các tầng lớp trung gian trong xã hội tham gia.  \n-  Thực chất của đấu tranh giai cấp là cuộc đấu tranh của quần chúng lao động \nbị áp bức, bóc lột chống lại giai cấp áp bức, bóc lột nhằm lật đổ ách thống trị của \nchúng.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 112}),
#  Document(page_content='chúng.  \n Trong xã hội có đối kháng giai cấp, thực chất đấu tranh giai cấp là cuộc đấu \ntranh của quần chúng lao động bị áp bức, bóc lột chống lại giai cấp áp bức, bóc lột do \nsự đối lập về lợi ích không thể dung hoà trong một chế độ kinh tế - xã hội nhất định.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 112}),
#  Document(page_content='Cách m ạng xã hội là phương thức tất yếu để lật đổ ách thống trị của giai cấp thống trị \nbóc lột, xoá bỏ quan hệ sản xuất cũ, xây dựng quan hệ sản xuất mới và mở đường cho \nlực lượng sản xuất phát triển. Mục đích cao nhất mà một cuộc đấu tranh giai cấp cần \nđạt được  không phải là đánh đổ một giai cấp cụ thể, mà là giải phóng lực lượng sản', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 112}),
#  Document(page_content='xuất khỏi sự kim hãm của những quan hệ sản xuất đã lỗi thời, tạo điều kiện để đẩy \nnhanh sự phát triển của lực lượng sản xuất và phát triển xã hội.  \nĐấu tranh giai cấp không phải là h iện tượng vĩnh viễn trong lịch sử. Cuộc đấu \ntranh giai cấp giữa các giai trong lịch sử tất yếu phát triển đến cuộc đấu tranh giai cấp', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 112}),
#  Document(page_content='của giai cấp vô sản. Đây là cuộc đấu tranh giai cấp cuối cùng trong lịch sử. Trong cuộc \nđấu tranh này, giai cấp vô sản đứn g lên giành chính quyền, thiết lập nền chuyên chính \ncủa mình và thông qua nền chuyên chính đó tiến hành cải tạo triệt để xã hội cũ, tiến tới \nxoá bỏ mọi đối kháng giai cấp, xây dựng thành công xã hội cộng sản chủ nghĩa.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 112}),
#  Document(page_content='Trong đấu tranh giai cấp, liên minh giai cấp  là tất yếu . Liên minh giai cấp là sự \nliên kết giữa những giai cấp này để chống lại những giai cấp khác.Liên minh giai cấp \nlà vấn đề có ý nghĩa cực kỳ quan trọng để tập hợp và phát triển lực lượng trong các \ncuộc đấu tranh giai cấp. Cơ sở của liên m inh giai cấp là sự thống nhất về lợi ích cơ', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 112}),
#  Document(page_content='BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN   \n \n  \n \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 112 bản. Liên minh giai cấp có tính chiến lược lâu dài khi các giai cấp có lợi ích căn bản \nthống nhất với nhau. Ngược lại, sẽ là sách lược tạm thời khi dựa trên cơ sở sự thống', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 113}),
#  Document(page_content='nhất về những lợi ích trước mắt không cơ  bản. Đấu tranh giai cấp và liên minh giai cấp \nluôn gắn bó hữu cơ với nhau. Đó là hai mặt của một quá trình để tạo nên sức mạnh \nnhằm giành thắng lợi trong một cuộc đấu tranh giai cấp.  \n* Vai trò của đấu tranh giai cấp trong sự phát triển của xã hội có giai  cấp', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 113}),
#  Document(page_content='Trong xã hội có giai cấp, đấu tranh giai cấp là động lực quan trọng, trực tiếp \ncủa lịch sử.  C.Mác và Ph. Ăngghen luôn nhấn mạnh vai trò của đấu tranh giai cấp, đặc \nbiệt là cuộc đấu tranh giai cấp giữa giai cấp tư sản và giai cấp vô sản, coi đó là "đò n \nbẩy vĩ đại của cuộc cách mạng xã hội hiện đại".', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 113}),
#  Document(page_content='Đấu tranh giai cấp đạt tới đỉnh cao thường dẫn đến cách mạng xã hội. Thông qua \ncách mạng xã hội mà quan hệ sản xuất cũ được xoá bỏ, quan hệ sản xuất mới phù hợp \nvới trình độ phát triển của lực lượng sản xuấ t được xác lập. Khi cơ sở kinh tế mới đã \nđã hình thành phát triển thì kiến trúc thượng tầng mới sớm hay muộn cũng ra đời, phát', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 113}),
#  Document(page_content='triển theo, xã hội thực hiện bước chuyển từ hình thái kinh tế - xã hội thấp lên hình thái \nkinh tế - xã hội cao hơn, tiến bộ hơn.  \nVai trò là động lực của đấu tranh giai cấp còn được thể hiện trong những thời kỳ \ntiến hoá xã hội. Ngay trong phạm vi vận động của một hình thái kinh tế - xã hội, đấu', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 113}),
#  Document(page_content='tranh giai cấp thường xuyên tác động thúc đẩy sự phát triển mọi mặt của đời sống xã \nhội. Thực tiễn cho thấy, sự phát triển của kinh tế, chính trị, văn hoá và ngay cả tư \ntưởng, lý luận của xã hội.v.v... đều là sản phẩm ít, hoặc nhiều mang dấu ấn của cuộc \nđấu tranh giai cấp. Đấu tranh giai cấp chẳng những có tác dụng cải tạo xã hội, xoá bỏ', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 113}),
#  Document(page_content='các l ực lượng xã hội phản động, mà còn có tác dụng cải tạo bản thân các giai cấp cách \nmạng. Thông qua thực tiễn đấu tranh giai cấp, giai cấp cách mạng có sự trưởng thành \nvề mọi mặt. Các giai cấp cách mạng cũng phải tự nâng mình lên đáp ứng được yêu cầu \ncủa lịch  sử.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 113}),
#  Document(page_content='của lịch  sử. \nĐấu tranh giai cấp là động lực phát triển của xã hội có giai cấp. Song vai trò là \nđộng lực của các cuộc đấu tranh giai cấp trong lịch sử không giống nhau. Vai trò của \nđấu tranh giai cấp đến mức độ nào điều đó phụ thuộc vào quy mô, tính chất của các', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 113}),
#  Document(page_content='nhiệm vụ kinh tế, chính trị, xã hội mà mỗi cuộc đấu tranh giai cấp phải giải quyết. \nCuộc đấu tranh giai cấp của giai cấp vô sản chống giai cấp tư sản là cuộc đấu tranh \ngiai cấp cuối cùng trong lịch sử. Do tính chất, quy mô rộng lớn và triệt để của các \nnhiệm vụ mà nó phải giải quyết, vì vậy đấu tranh giai cấp của giai cấp vô sản là "đòn', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 113}),
#  Document(page_content='bẩy vĩ đại nhất" trong lịch sử xã hội có giai cấp.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 113}),
#  Document(page_content='BÀI GI ẢNG MÔN TRI ẾT HỌC MÁC - LÊNIN   \n \n  \n \nBỘ MÔN LÝ LU ẬN CHÍNH TR Ị - PTIT Page 113  Đấu tranh giai cấp là động lực phát triển của xã hội, nhưng không phải là động \nlực duy nhất mà là một động lực trực tiếp và  quan trọng . Vì vậy, trong đấu tranh cách \nmạng cần phải xác định hệ thống các động lực của xã hội, có nghệ thuật sử dụng', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 114}),
#  Document(page_content='những động lực đó để giải phóng giai cấp và thúc đẩy xã hội phát triển.  \nc. Đấu tranh giai cấp của giai cấp vô sản  \n* Đấu tranh giai cấp  của giai cấp vô sản khi chưa có chính quyền  \nTổng kết thực tiễn cuộc đấu tranh giai cấp của giai cấp vô sản khi chưa giành \nđược chính quyền, C.Mác và Ph.Ăngghen đã khái quát và chỉ ra ba hình thức đấu tranh', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 114}),
#  Document(page_content='cơ bản, đó là đấu tranh kinh tế; đấu tranh chính trị và đấu tranh tư tưởng.  \n- Đấu tranh kinh tế  là một trong những hình thức cơ bản đấu tranh giai cấp của \ngiai cấp vô sản. Đấu tranh kinh tế có nhiệm vụ trước mắt là bảo vệ những lợi ích hàng \nngày của công nhân như tăng lương, rút ngắn thời gian lao động, cải thiện điều kiện', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 114}),
#  Document(page_content='sống v.v…Đấu tranh kinh tế bao gồm nhiều hình thức đa dạng và có vai trò rất quan \ntrọng nhằm bảo vệ lợi ích kinh tế của giai cấp vô sản . Ngoài ra, đấu tranh kinh tế còn \ncó tác dụng tập hợp lực lượng, giác ngộ quần chúng trong cuộc đấu t ranh giai cấp nói \nchung. Tuy nhiên, đấu tranh kinh tế chỉ hạn chế chứ không thể xoá bỏ được sự bóc lột', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 114}),
#  Document(page_content='của giai cấp tư sản, không thể đạt được mục đích cuối cùng là xoá bỏ chế độ tư bản \nchủ nghĩa.  \n- Đấu tranh chính trị  là hình thức đấu tranh cao nhất của giai cấp vô sản. Mục \ntiêu của đấu tranh chính trị là đánh đổ ách thống trị của giai cấp tư sản, phản động,', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 114}),
#  Document(page_content='giành chính quyền về tay giai cấp vô sản. Đấu tranh chính trị có nhiều hình thức cụ thể \nvà trình độ khác nhau.  \n- Đấu tranh tư tưởng  có mục đích đập tan hệ tư tưởng của giai cấp tư sản, khắc \nphục những ảnh hưởng của tư tưởng, tâm lý, tập quán lạc hậu trong phong trào cách', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 114}),
#  Document(page_content='mạng; vũ trang cho họ hệ tư tưởng cách mạng và khoa học của giai cấp công nhân, đó \nlà chủ nghĩa Mác - Lênin. Ngoài ra, đấu tranh tư tưởng còn nhằm giáo dục quần chúng \nnhân dân lao động thấm nhuần đường lối chiến lược, sách lược cách mạng của đảng, \nbiến đường lối cách mạng của đảng thành hành động cách mạng.', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 114}),
#  Document(page_content='Ba hình thức đấu tranh cơ bản của giai cấp vô sản có quan hệ chặt chẽ với nhau , \nhỗ trợ lẫn nhau, nhưng có vai trò không ngang bằng nhau. Trong thực tế, các hình thức \nđấu tranh kinh tế, đấu tranh chính trị và đấu tranh tư tưởng được sử dụng đan xen \nnhau. Chúng vừa là tiền đề, vừa là cơ sở của nhau, thống nhất với nhau, bổ trợ lẫn', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 114}),
#  Document(page_content='nhau và đều dẫn tới mục tiêu cao nhất. Trong đó, đấu tranh chính trị là hình thức đấu \ntranh cao nhất, có ý nghĩa quyết định đến thắng lợi của giai cấp vô sản. Nhưng việc sử \ndụng các hình thức đấu tranh nào, ở những giai đoạn cụ thể nào của cuộc đấu tranh là', metadata={'source': '/content/helo/BAI GIANG TRIET 2021 (1).pdf', 'page': 114}),
#  ...]

# %%
# Install PyTorch for Mac or Windows PC without Nvidia GPU
# !pip install torch torchvision torchaudio

# !pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading sentence_transformers-2.4.0-py3-none-any.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.5/149.5 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.37.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.1.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (0.4.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# Installing collected packages: sentence_transformers
# Successfully installed sentence_transformers-2.4.0

# %%
import torch
# Detect hardware acceleration device
if torch.cuda.is_available():
    device = 'cuda'
elif torch.backends.mps.is_available():
    device = 'mps'
else:
    device = 'cpu'

print(f'Using device: {device}')
# Out:
# Using device: cuda

# %% [markdown]
# #### Load embedding model:
# A good place to start when choosing and embedding model is the [MTEB English Leaderboard](https://huggingface.co/BAAI/bge-small-en)
#
# At time of writing, the [BAAI/bge-small-en-v1.5'model](https://huggingface.co/spaces/mteb/leaderboard) is the best small model according to the leaderboard

# %%
from langchain.embeddings import HuggingFaceBgeEmbeddings
model_name = 'bkai-foundation-models/vietnamese-bi-encoder'  # Using open source embedding model

embedding_function = HuggingFaceBgeEmbeddings(
    model_name=model_name,
    model_kwargs={'device': device},
    encode_kwargs={'normalize_embeddings': True} #normalizes the vectors
)
print(f'Loaded {model_name} from HuggingFace')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/6.08k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/701 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/540M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# tokenizer_config.json:   0%|          | 0.00/303 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/895k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.14M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Loaded bkai-foundation-models/vietnamese-bi-encoder from HuggingFace

# %% [markdown]
# ### 4. Create and store the Vector DB
# * This will use the bge-small-en embeddings model to embed our chunked text into vectors
# * Then save those vectors into a ChromaDB named "LC_VectorDB"
#
# **Note**: If a DB with that name already exists, it will append, otherwise it creates it

# %%
persist_directory = 'LC_VectorDB' # Name of the DB

vectordb = Chroma.from_documents(
    documents=chunks,
    embedding=embedding_function,
    persist_directory=persist_directory # This line saves the db to disk
    )
print("DB write complete!")
# Out:
# DB write complete!

# %%
import zipfile
import os

def zip_directory(directory_path, output_path):
    with zipfile.ZipFile(output_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(directory_path):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, directory_path))

# Đường dẫn của thư mục bạn muốn nén
directory_path = '/content/LC_VectorDB'

# Đường dẫn và tên file zip đầu ra
output_path = '/content/alo.zip'

# Gọi hàm để nén thư mục
zip_directory(directory_path, output_path)
